# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from combinationFnBlock import TimeEmbedding
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
#  The Device is : cpu

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f" The Device is : {device}")
# Out:
#  The Device is : cpu

# %%
x0 = torch.randn(2, 64, 768)
noise = torch.rand_like(x0)

target = x0 - noise
tEmbed = TimeEmbedding(768)
tEmbed.to(device)
time = torch.tensor([0.1]).to(device)
t_ = tEmbed(time)
x_t = (1 - t_[:, None]) * noise + t_[:, None] * x0

# %%
# // model predicted at time t --> xt
steps = 100
for i, t in enumerate(torch.linspace(0, 1, steps), start=1):
    predicted = torch.randn(2, 64, 768)
    x_t = x_t + (1/steps) * predicted    
x_t.shape
# Out:
# torch.Size([2, 64, 768])
